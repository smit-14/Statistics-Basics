# %% [markdown]
# **ASSIGNMENT QUESTIONS**

# %% [markdown]
# 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss nominal, ordinal, interval, and ratio scales.
#
# - Qualitative data (Categorical) describes characteristics or qualities and cannot be measured numerically. Examples: colors, gender, nationality.
#
# - Quantitative data (Numerical) consists of measurable values. Examples: height, weight, income.
#
# - Nominal scale: Categorical data without any order (e.g., eye color, gender).
#
# - Ordinal scale: Categorical data with a meaningful order (e.g., rankings, survey ratings).
#
# - Interval scale: Numeric data with equal intervals but no true zero (e.g., temperature in Celsius).
#
# - Ratio scale: Numeric data with a true zero, allowing for meaningful ratios (e.g., weight, height, income).
#
# 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median, and mode with examples and situations where each is appropriate.
#
# - Mean: The average of all data points. Best for symmetric distributions without outliers (e.g., average test scores).
#
# - Median: The middle value in an ordered dataset. Best when dealing with skewed distributions (e.g., income data).
#
# - Mode: The most frequently occurring value. Useful for categorical data or identifying common trends (e.g., most common shoe size).
#
# 3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#
# - Dispersion refers to how spread out the data points are.
#
# - Variance: Measures the average squared deviation from the mean.
#
# - Standard deviation: The square root of variance, representing the typical deviation from the mean.
#
# 4. What is a box plot, and what can it tell you about the distribution of data?
#
# - A box plot (or box-and-whisker plot) displays data distribution, showing the median, quartiles, and potential outliers.
#
# - It provides insights into skewness, spread, and outliers in the dataset.
#
# 5. Discuss the role of random sampling in making inferences about populations.
#
# - Random sampling ensures every individual has an equal chance of selection, reducing bias.
#
# - It helps in making unbiased estimates about a population based on sample data.
#
# - Techniques include simple random sampling, stratified sampling, and cluster sampling.
#
# 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#
# - Skewness describes asymmetry in data distribution.
#
# - Positive skew: Tail on the right, with the mean greater than the median (e.g., income distribution).
#
# - Negative skew: Tail on the left, with the mean less than the median (e.g., age of retirement).
#
# - Skewness impacts measures of central tendency and data interpretation.
#
# 7. What is the interquartile range (IQR), and how is it used to detect outliers?
#
# - IQR = Q3 - Q1, where Q1 (25th percentile) and Q3 (75th percentile) define the middle 50% of data.
#
# - Outliers are values below Q1 - 1.5 × IQR or above Q3 + 1.5 × IQR.
#
# 8. Discuss the conditions under which the binomial distribution is used.
#
# - The binomial distribution applies when:
#
#   - There are n independent trials.
#
#   - Each trial has two possible outcomes (success or failure).
#
#   - The probability of success (p) is constant for all trials.
#
#   - The trials are independent.
#
# 9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
#
# - Normal distribution is symmetric, bell-shaped, and characterized by mean (μ) and standard deviation (σ).
#
# - Empirical Rule:
#
#     68% of data falls within 1σ of the mean.
#
#     95% falls within 2σ.
#
#     99.7% falls within 3σ.
#
# 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
#
# - Example: Number of customer calls received per hour in a call center.
#
# - Poisson probability formula:
#
#     𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝑒
# −
# 𝜆
# 𝜆
# 𝑘
# 𝑘
# !
# P(X=k)=
# k!
# e
# −λ
#  λ
# k
# - where λ is the average rate and k is the number of occurrences.
#
# 11. Explain what a random variable is and differentiate between discrete and continuous random variables.
#
# - A random variable assigns numerical values to outcomes of a random process.
#
# - Discrete random variables: Countable values (e.g., number of students in a class).
#
# - Continuous random variables: Infinite possible values (e.g., height, temperature).
#
# 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
#
# - Example dataset:
#
#     X = [2, 4, 6, 8, 10]
#
#     Y = [3, 6, 9, 12, 15]
#
# - Covariance measures how two variables change together.
#
# - Correlation standardizes covariance, ranging from -1 to 1.
#
# - A positive correlation indicates a direct relationship, while negative correlation suggests an inverse relationship.
